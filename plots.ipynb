# %%
from data_extraction import *

# %%
all_banks = [['privatbank', 'lime'], ['oschadbank', 'black'], ['sense', 'blue'],
             ['ukreximbank', 'magenta'], ['ukrgasbank', 'red'], ['first investment bank', 'orange']]

# %%
all_all_banks = all_banks
plot_donut_chart('data/original/total_assets.csv', '2024-05', all_all_banks)

# %%
plot_stacked_area_chart('data/original/total_assets.csv', all_banks)

# %%
plot_HHI('data/market_share/TA.csv')
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plot_theil('data/market_share/TA.csv')
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
for bank in ['ПриватБанк', 'Ощадбанк', 'Укрексімбанк', 'УКРГАЗБАНК', 'СЕНС БАНК', 'ПЕРШИЙ ІНВЕСТИЦІЙНИЙ БАНК']:
    plot_bank_filials(bank)
